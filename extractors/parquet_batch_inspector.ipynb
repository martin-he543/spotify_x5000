# %% [markdown]
# # Live Parquet Batch Inspector (Extractor v8 format)
# Inspect extraction checkpoints from `batch_results/results_batch_*` as they are being generated by `spotify_extractor_v8.ipynb`.
#
# This notebook supports both `.parquet` and `.pkl` checkpoints (same behavior as extractor v8).

# %%
from pathlib import Path
from datetime import datetime
import re
import time

import polars as pl
import pandas as pd

# Must match spotify_extractor_v8.ipynb
BATCH_DIR = Path('batch_results')
PATTERN = 'results_batch_*'

print(f'Watching batch directory: {BATCH_DIR.resolve()}')
# Out:
# Watching batch directory: /home/build/martin/spotify_v2/batch_results

# %%
def list_checkpoint_files(batch_dir: Path = BATCH_DIR):
    files = sorted(
        [p for p in batch_dir.glob(PATTERN) if p.suffix in {'.parquet', '.pkl'}],
        key=lambda p: p.name
    )
    return files


def parse_batch_index(path: Path) -> int | None:
    m = re.search(r'results_batch_(\d+)', path.name)
    return int(m.group(1)) if m else None


checkpoint_files = list_checkpoint_files()
print(f'Found {len(checkpoint_files)} checkpoint files.')
for p in checkpoint_files[-10:]:
    print(' -', p.name)
# Out:
# Found 281 checkpoint files.
#  - results_batch_00272.parquet
#  - results_batch_00273.parquet
#  - results_batch_00274.parquet
#  - results_batch_00275.parquet
#  - results_batch_00276.parquet
#  - results_batch_00277.parquet
#  - results_batch_00278.parquet
#  - results_batch_00279.parquet
#  - results_batch_00280.parquet
#  - results_batch_00281.parquet

# %%
if checkpoint_files:
    summary_rows = []
    for p in checkpoint_files:
        stat = p.stat()
        summary_rows.append({
            'batch_index': parse_batch_index(p),
            'file': p.name,
            'format': p.suffix.replace('.', ''),
            'size_mb': round(stat.st_size / (1024 * 1024), 3),
            'modified_at': datetime.fromtimestamp(stat.st_mtime).strftime('%Y-%m-%d %H:%M:%S'),
        })

    files_df = pl.DataFrame(summary_rows).sort('batch_index')
    display(files_df)
else:
    files_df = pl.DataFrame()
    print('No checkpoint files found yet.')

files_df
# Out:
# shape: (281, 5)
# ┌─────────────┬─────────────────────────────┬─────────┬─────────┬─────────────────────┐
# │ batch_index ┆ file                        ┆ format  ┆ size_mb ┆ modified_at         │
# │ ---         ┆ ---                         ┆ ---     ┆ ---     ┆ ---                 │
# │ i64         ┆ str                         ┆ str     ┆ f64     ┆ str                 │
# ╞═════════════╪═════════════════════════════╪═════════╪═════════╪═════════════════════╡
# │ 1           ┆ results_batch_00001.parquet ┆ parquet ┆ 2.504   ┆ 2026-03-15 10:58:59 │
# │ 2           ┆ results_batch_00002.parquet ┆ parquet ┆ 4.934   ┆ 2026-03-15 11:07:50 │
# │ 3           ┆ results_batch_00003.parquet ┆ parquet ┆ 3.294   ┆ 2026-03-15 11:13:12 │
# │ 4           ┆ results_batch_00004.parquet ┆ parquet ┆ 6.887   ┆ 2026-03-15 11:22:07 │
# │ 5           ┆ results_batch_00005.parquet ┆ parquet ┆ 4.626   ┆ 2026-03-15 11:28:12 │
# │ …           ┆ …                           ┆ …       ┆ …       ┆ …                   │
# │ 277         ┆ results_batch_00277.parquet ┆ parquet ┆ 2.934   ┆ 2026-03-16 17:47:55 │
# │ 278         ┆ results_batch_00278.parquet ┆ parquet ┆ 3.049   ┆ 2026-03-16 17:51:41 │
# │ 279         ┆ results_batch_00279.parquet ┆ parquet ┆ 2.633   ┆ 2026-03-16 17:55:37 │
# │ 280         ┆ results_batch_00280.parquet ┆ parquet ┆ 2.213   ┆ 2026-03-16 17:59:27 │
# │ 281         ┆ results_batch_00281.parquet ┆ parquet ┆ 2.304   ┆ 2026-03-16 18:03:07 │
# └─────────────┴─────────────────────────────┴─────────┴─────────┴─────────────────────┘
# shape: (281, 5)
# ┌─────────────┬─────────────────────────────┬─────────┬─────────┬─────────────────────┐
# │ batch_index ┆ file                        ┆ format  ┆ size_mb ┆ modified_at         │
# │ ---         ┆ ---                         ┆ ---     ┆ ---     ┆ ---                 │
# │ i64         ┆ str                         ┆ str     ┆ f64     ┆ str                 │
# ╞═════════════╪═════════════════════════════╪═════════╪═════════╪═════════════════════╡
# │ 1           ┆ results_batch_00001.parquet ┆ parquet ┆ 2.504   ┆ 2026-03-15 10:58:59 │
# │ 2           ┆ results_batch_00002.parquet ┆ parquet ┆ 4.934   ┆ 2026-03-15 11:07:50 │
# │ 3           ┆ results_batch_00003.parquet ┆ parquet ┆ 3.294   ┆ 2026-03-15 11:13:12 │
# │ 4           ┆ results_batch_00004.parquet ┆ parquet ┆ 6.887   ┆ 2026-03-15 11:22:07 │
# │ 5           ┆ results_batch_00005.parquet ┆ parquet ┆ 4.626   ┆ 2026-03-15 11:28:12 │
# │ …           ┆ …                           ┆ …       ┆ …       ┆ …                   │
# │ 277         ┆ results_batch_00277.parquet ┆ parquet ┆ 2.934   ┆ 2026-03-16 17:47:55 │
# │ 278         ┆ results_batch_00278.parquet ┆ parquet ┆ 3.049   ┆ 2026-03-16 17:51:41 │
# │ 279         ┆ results_batch_00279.parquet ┆ parquet ┆ 2.633   ┆ 2026-03-16 17:55:37 │
# │ 280         ┆ results_batch_00280.parquet ┆ parquet ┆ 2.213   ┆ 2026-03-16 17:59:27 │
# │ 281         ┆ results_batch_00281.parquet ┆ parquet ┆ 2.304   ┆ 2026-03-16 18:03:07 │
# └─────────────┴─────────────────────────────┴─────────┴─────────┴─────────────────────┘

# %%
def read_checkpoint(path: Path) -> pl.DataFrame:
    if path.suffix == '.parquet':
        return pl.read_parquet(path)
    if path.suffix == '.pkl':
        return pl.from_pandas(pd.read_pickle(path))
    return pl.DataFrame()


def load_checkpoints(files: list[Path], latest_n: int | None = None) -> pl.DataFrame:
    use_files = files[-latest_n:] if latest_n else files
    frames = []

    for p in use_files:
        try:
            df_part = read_checkpoint(p).with_columns(pl.lit(p.name).alias('_source_file'))
            frames.append(df_part)
        except Exception as e:
            print(f'Skipping unreadable file {p.name}: {e}')

    if not frames:
        return pl.DataFrame()

    return pl.concat(frames, how='diagonal_relaxed')


# Set latest_n=None to load everything, or an int (e.g. 5) for quicker live checks
latest_n = None
results_df = load_checkpoints(checkpoint_files, latest_n=latest_n)

print(f'Loaded rows: {results_df.height:,}')
print(f'Columns: {results_df.width}')
display(results_df.head(10))
# Out:
# Loaded rows: 281,000
# Columns: 20
# shape: (10, 20)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │
# │ ZIxcsnKNg ┆ Way You   ┆ Avenue    ┆ ZIxcsnKNg ┆   ┆           ┆ eyes, her ┆           ┆ batch_00 │
# │ tMLx      ┆ Are       ┆           ┆ tMLx      ┆   ┆           ┆ eyes      ┆           ┆ 001.parq │
# │           ┆           ┆           ┆           ┆   ┆           ┆ Make the… ┆           ┆ uet      │
# │ 6nXIYClvJ ┆ Sky's     ┆ Andrew    ┆ 6nXIYClvJ ┆ … ┆ ok        ┆ You never ┆ ok_lrclib ┆ results_ │
# │ Afi6ujLiK ┆ Still     ┆ Belle     ┆ Afi6ujLiK ┆   ┆           ┆ see       ┆           ┆ batch_00 │
# │ qEq8      ┆ Blue      ┆           ┆ qEq8      ┆   ┆           ┆ clearly,  ┆           ┆ 001.parq │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 'til yo…  ┆           ┆ uet      │
# │ 0AYG9Acwq ┆ The Woman ┆ Jason     ┆ 0AYG9Acwq ┆ … ┆ ok        ┆ Maybe I   ┆ ok_lrclib ┆ results_ │
# │ EeqgAw3Ov ┆ I Love    ┆ Mraz      ┆ EeqgAw3Ov ┆   ┆           ┆ annoy you ┆           ┆ batch_00 │
# │ shPC      ┆           ┆           ┆ shPC      ┆   ┆           ┆ with my   ┆           ┆ 001.parq │
# │           ┆           ┆           ┆           ┆   ┆           ┆ choi…     ┆           ┆ uet      │
# │ 3SUY9IKXc ┆ Ouija     ┆ Harley    ┆ 3SUY9IKXc ┆ … ┆ ok        ┆ Gonna     ┆ ok_lrclib ┆ results_ │
# │ U5VN95FOu ┆           ┆ Poe       ┆ U5VN95FOu ┆   ┆           ┆ play a    ┆           ┆ batch_00 │
# │ jS6S      ┆           ┆           ┆ jS6S      ┆   ┆           ┆ show at a ┆           ┆ 001.parq │
# │           ┆           ┆           ┆           ┆   ┆           ┆ house t…  ┆           ┆ uet      │
# │ 6VtoP2sJt ┆ Someone   ┆ Boyce     ┆ 6VtoP2sJt ┆ … ┆ ok        ┆ I heard   ┆ ok_lrclib ┆ results_ │
# │ 5oCmPOQIv ┆ Like You  ┆ Avenue    ┆ 5oCmPOQIv ┆   ┆           ┆ that      ┆           ┆ batch_00 │
# │ e2sf      ┆           ┆           ┆ e2sf      ┆   ┆           ┆ you're    ┆           ┆ 001.parq │
# │           ┆           ┆           ┆           ┆   ┆           ┆ settled   ┆           ┆ uet      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ do…       ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
EXPECTED_BASE_COLS = [
    'track_id', 'original_name', 'original_artist',
    'metadata_status', 'lyrics', 'lyrics_status'
]

if results_df.is_empty():
    print('No loaded rows to inspect yet.')
else:
    missing = [c for c in EXPECTED_BASE_COLS if c not in results_df.columns]
    if missing:
        print('Missing expected extractor-v8 columns:', missing)
    else:
        print('Extractor-v8 base columns found.')

    if 'track_id' in results_df.columns:
        unique_tracks = results_df.select(pl.col('track_id').cast(pl.Utf8).n_unique()).item()
        duplicates = results_df.height - unique_tracks
        print(f'Unique track_id: {unique_tracks:,}')
        print(f'Duplicate rows by track_id: {duplicates:,}')

    if 'lyrics_status' in results_df.columns:
        status_counts = (
            results_df
            .with_columns(pl.col('lyrics_status').cast(pl.Utf8).fill_null('null').alias('lyrics_status'))
            .group_by('lyrics_status')
            .len()
            .sort('len', descending=True)
        )
        display(status_counts)

        print('\nFull status_counts (no truncation):')
        print('lyrics_status | len')
        print('-' * 80)
        for row in status_counts.iter_rows(named=True):
            print(f"{row['lyrics_status']} | {row['len']}")

        ok_count = results_df.filter(pl.col('lyrics_status').cast(pl.Utf8).str.contains('ok', literal=True)).height
        not_found_only = results_df.filter(
            pl.col('lyrics_status').cast(pl.Utf8).str.contains('not_found', literal=True)
            & ~pl.col('lyrics_status').cast(pl.Utf8).str.contains('ok', literal=True)
        ).height
        print(f'\n\nTotal "ok" count (including variants): {ok_count:,}')
        print(f'Total "not_found" count (without ok fallback): {not_found_only:,}')
# Out:
# Extractor-v8 base columns found.
# Unique track_id: 281,000
# Duplicate rows by track_id: 0
# shape: (52, 2)
# ┌─────────────────────────────────┬────────┐
# │ lyrics_status                   ┆ len    │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ ok_lrclib                       ┆ 163220 │
# │ not_found_lrclib->error_librel… ┆ 42163  │
# │ not_found_lrclib->error_librel… ┆ 30328  │
# │ not_found_lrclib->error_librel… ┆ 15103  │
# │ instrumental_lrclib->error_lib… ┆ 5978   │
# │ …                               ┆ …      │
# │ instrumental_lrclib->error_lib… ┆ 1      │
# │ http_400_lrclib->error_librely… ┆ 1      │
# │ not_found_lrclib->error_librel… ┆ 1      │
# │ not_found_lrclib->error_librel… ┆ 1      │
# │ not_found_lrclib->error_librel… ┆ 1      │
# └─────────────────────────────────┴────────┘
# Full status_counts (no truncation):
# lyrics_status | len
# --------------------------------------------------------------------------------
# ok_lrclib | 163220
# not_found_lrclib->error_librelyrics: LyricsNotFound->bot_block_genius->not_found_synced | 42163
# not_found_lrclib->error_librelyrics: LyricsNotFound->not_found_genius->not_found_synced | 30328
# not_found_lrclib->error_librelyrics: LyricsNotFound->ok_genius | 15103
# instrumental_lrclib->error_librelyrics: LyricsNotFound->not_found_genius->not_found_synced | 5978
# instrumental_lrclib->error_librelyrics: LyricsNotFound->bot_block_genius->not_found_synced | 4744
# not_found_lrclib->error_librelyrics: LyricsNotFound->bot_block_genius->ok_synced | 4294
# not_found_lrclib->skipped_no_auth->ok_genius | 3202
# not_found_lrclib->ok_librelyrics | 2790
# not_found_lrclib->skipped_no_auth->not_found_genius->not_found_synced | 2486
# not_found_lrclib->error_librelyrics: LyricsNotFound->not_found_genius->ok_synced | 1807
# instrumental_lrclib->error_librelyrics: LyricsNotFound->ok_genius | 1520
# not_found_lrclib->error_librelyrics: NotValidSp_Dc->bot_block_genius->not_found_synced | 867
# not_found_lrclib->error_librelyrics: NotValidSp_Dc->ok_genius | 485
# instrumental_lrclib->skipped_no_auth->not_found_genius->not_found_synced | 470
# not_found_lrclib->error_librelyrics: NotValidSp_Dc->not_found_genius->not_found_synced | 451
# instrumental_lrclib->skipped_no_auth->ok_genius | 231
# instrumental_lrclib->error_librelyrics: NotValidSp_Dc->bot_block_genius->not_found_synced | 181
# not_found_lrclib->skipped_no_auth->not_found_genius->ok_synced | 136
# instrumental_lrclib->error_librelyrics: LyricsNotFound->not_found_genius->ok_synced | 86
# instrumental_lrclib->error_librelyrics: LyricsNotFound->bot_block_genius->ok_synced | 84
# instrumental_lrclib->ok_librelyrics | 76
# not_found_lrclib->error_librelyrics: NotValidSp_Dc->bot_block_genius->ok_synced | 62
# http_400_lrclib->error_librelyrics: LyricsNotFound->not_found_genius->not_found_synced | 40
# http_400_lrclib->error_librelyrics: LyricsNotFound->bot_block_genius->not_found_synced | 36
# not_found_lrclib->skipped_no_auth->bot_block_genius->not_found_synced | 33
# instrumental_lrclib->error_librelyrics: NotValidSp_Dc->ok_genius | 32
# instrumental_lrclib->error_librelyrics: NotValidSp_Dc->not_found_genius->not_found_synced | 21
# not_found_lrclib->error_librelyrics: NotValidSp_Dc->not_found_genius->ok_synced | 14
# not_found_lrclib->error_librelyrics: ProviderError->bot_block_genius->not_found_synced | 12
# not_found_lrclib->error_librelyrics: ProviderError->not_found_genius->not_found_synced | 8
# instrumental_lrclib->skipped_no_auth->bot_block_genius->not_found_synced | 7
# http_400_lrclib->error_librelyrics: LyricsNotFound->ok_genius | 5
# instrumental_lrclib->error_librelyrics: ProviderError->bot_block_genius->not_found_synced | 2
# http_400_lrclib->skipped_no_auth->ok_genius | 2
# instrumental_lrclib->skipped_no_auth->not_found_genius->ok_synced | 2
# not_found_lrclib->error_librelyrics: LyricsNotFound->not_found_genius->empty_synced | 2
# http_400_lrclib->skipped_no_auth->not_found_genius->not_found_synced | 2
# not_found_lrclib->error_librelyrics: LyricsNotFound->error_genius->not_found_synced | 2
# not_found_lrclib->error_librelyrics: AttributeError->not_found_genius->not_found_synced | 2
# instrumental_lrclib->error_librelyrics: NotValidSp_Dc->bot_block_genius->ok_synced | 2
# instrumental_lrclib->error_librelyrics: LyricsNotFound->error_genius->not_found_synced | 2
# http_400_lrclib->error_librelyrics: LyricsNotFound->bot_block_genius->ok_synced | 1
# not_found_lrclib->error_librelyrics: ProviderError->ok_genius | 1
# not_found_lrclib->skipped_no_auth->bot_block_genius->ok_synced | 1
# not_found_lrclib->error_librelyrics: AttributeError->ok_genius | 1
# not_found_lrclib->error_librelyrics: ProviderError->bot_block_genius->ok_synced | 1
# instrumental_lrclib->error_librelyrics: ProviderError->ok_genius | 1
# http_400_lrclib->error_librelyrics: NotValidSp_Dc->not_found_genius->not_found_synced | 1
# not_found_lrclib->error_librelyrics: AttributeError->bot_block_genius->not_found_synced | 1
# not_found_lrclib->error_librelyrics: LyricsNotFound->error_genius->ok_synced | 1
# not_found_lrclib->error_librelyrics: TOTPGenerationException->not_found_genius->not_found_synced | 1
#
#
# Total "ok" count (including variants): 193,160
# Total "not_found" count (without ok fallback): 87,840

# %%
# Quick check of the latest written checkpoint
if checkpoint_files:
    latest_file = checkpoint_files[-1]
    latest_df = read_checkpoint(latest_file)
    print(f'Latest file: {latest_file.name}')
    print(f'Rows in latest file: {latest_df.height:,}')
    print(f'Cols in latest file: {latest_df.width}')
    display(latest_df.head(10))

    if 'lyrics_status' in latest_df.columns:
        latest_status = latest_df.group_by('lyrics_status').len().sort('len', descending=True)
        display(latest_status)
else:
    print('No checkpoint files found.')
# Out:
# Latest file: results_batch_00281.parquet
# Rows in latest file: 1,000
# Cols in latest file: 19
# shape: (10, 19)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │
┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ man'…     ┆          │
# │ 4mlfHtGdY ┆ Sobre Nós ┆ Grupo Bom ┆ 4mlfHtGdY ┆ … ┆ 2021-08-1 ┆ ok        ┆ Sim       ┆ not_foun │
# │ ycfeKrd54 ┆ - Ao Vivo ┆ Astral    ┆ ycfeKrd54 ┆   ┆ 1         ┆           ┆ Meu       ┆ d_lrclib │
# │ Utdq      ┆           ┆           ┆ Utdq      ┆   ┆           ┆           ┆ estado    ┆ ->error_ │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ mental    ┆ librel…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ está com… ┆          │
# │ 4Zp3rm12p ┆ Meet      ┆ KIMSEJEON ┆ 4Zp3rm12p ┆ … ┆ 2020-12-2 ┆ ok        ┆ 언제 잠이 ┆ not_foun │
# │ 5PiHToYJf ┆ Again     ┆ G         ┆ 5PiHToYJf ┆   ┆ 0         ┆           ┆ 들어 여기 ┆ d_lrclib │
# │ lmyy      ┆           ┆           ┆ lmyy      ┆   ┆           ┆           ┆ 닿았나?   ┆ ->ok_lib │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 너의 모든 ┆ relyri…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 시간은    ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 멈춰버…   ┆          │
# │ 6RGk4ooM4 ┆ Elephants ┆ Them      ┆ 6RGk4ooM4 ┆ … ┆ 2009-11-1 ┆ ok        ┆ We're     ┆ ok_lrcli │
# │ yLouf6Lqe ┆           ┆ Crooked   ┆ yLouf6Lqe ┆   ┆ 7         ┆           ┆ painted   ┆ b        │
# │ 4pTR      ┆           ┆ Vultures  ┆ 4pTR      ┆   ┆           ┆           ┆ as        ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ monsters  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ Borr…     ┆          │
# │ 7eIODQbTg ┆ Love's    ┆ Cage The  ┆ 7eIODQbTg ┆ … ┆ 2019-04-1 ┆ ok        ┆ Looking   ┆ ok_lrcli │
# │ KeNawQtow ┆ The Only  ┆ Elephant  ┆ KeNawQtow ┆   ┆ 9         ┆           ┆ out my    ┆ b        │
# │ ZJEM      ┆ Way       ┆           ┆ ZJEM      ┆   ┆           ┆           ┆ window at ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ the c…    ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
# shape: (9, 2)
# ┌─────────────────────────────────┬─────┐
# │ lyrics_status                   ┆ len │
# │ ---                             ┆ --- │
# │ str                             ┆ u32 │
# ╞═════════════════════════════════╪═════╡
# │ ok_lrclib                       ┆ 852 │
# │ not_found_lrclib->error_librel… ┆ 55  │
# │ instrumental_lrclib->error_lib… ┆ 23  │
# │ not_found_lrclib->ok_librelyri… ┆ 23  │
# │ not_found_lrclib->error_librel… ┆ 22  │
# │ instrumental_lrclib->error_lib… ┆ 21  │
# │ not_found_lrclib->error_librel… ┆ 2   │
# │ instrumental_lrclib->error_lib… ┆ 1   │
# │ instrumental_lrclib->ok_librel… ┆ 1   │
# └─────────────────────────────────┴─────┘

# %%
# Optional live monitor: set rounds > 1 to auto-refresh
rounds = 1           # e.g. 20
sleep_seconds = 10   # e.g. 10

for i in range(1, rounds + 1):
    files_now = list_checkpoint_files()
    latest_name = files_now[-1].name if files_now else 'none'
    print(f'[{i}/{rounds}] files={len(files_now)} latest={latest_name}')

    if i < rounds:
        time.sleep(sleep_seconds)
# Out:
# [1/1] files=281 latest=results_batch_00281.parquet
