# %% [markdown]
# # Spotify Stream Count Extractor - Top 1000 Test
# Extract Spotify stream counts for the top 1000 tracks (sorted by popularity) in `spotify_data.parquet`.
# To speed up extraction, we use `spotify_scraper` to find the artist and then fetch the artist's total streaming data from `kworb.net`.

# %% [markdown]
# ## 1. Install and Import Required Libraries

# %%
# %pip install spotifyscraper bs4 requests pandas pyarrow --quiet
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import os
from pathlib import Path
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Load Dataset and Filter for Top 1000 Tracks

# %%
df = pd.read_parquet('spotify_data.parquet')
print(f"Loaded {len(df)} tracks.")

df_test = df.sort_values(by='popularity', ascending=False).head(30000).reset_index(drop=True)
print(f"Processing top {len(df_test)} tracks by popularity.")
# Out:
# Loaded 1159764 tracks.
# Processing top 30000 tracks by popularity.

# %% [markdown]
# ## 3. Configure Scraper & Kworb Helper

# %%
import spotify_scraper as sps
client = sps.SpotifyClient(log_level='WARNING')

def get_streams_kworb(track_id, track_name):
    try:
        # Fetch track info to get the primary artist ID
        info = client.get_track_info(f"https://open.spotify.com/track/{track_id}")
        if not info or 'artists' not in info or not info['artists']:
            return None
        
        artist_id = info['artists'][0]['id']
        
        # Fetch Kworb artist streaming page
        kworb_url = f"https://kworb.net/spotify/artist/{artist_id}_songs.html"
        resp = requests.get(kworb_url, timeout=5)
        if resp.status_code != 200:
            return None
        
        soup = BeautifulSoup(resp.text, 'html.parser')
        for tr in soup.find_all('tr'):
            cols = tr.find_all('td')
            if len(cols) >= 2:
                row_name = cols[0].get_text().strip()
                # Simple fuzzy match on track name
                if track_name.lower() in row_name.lower() or row_name.lower() in track_name.lower():
                    streams_str = cols[1].get_text().replace(',', '')
                    if streams_str.isdigit():
                        return int(streams_str)
        return None
    except Exception as e:
        print(f"Error for {track_name}: {e}")
        return None

# %% [markdown]
# ## 4. Extract Streams in Batches of 100
# Saves intermediate results to the `batch_results_streams` directory so we don't lose progress.

# %%
BATCH_SIZE = 100
BATCH_DIR = Path('batch_results_streams')
BATCH_DIR.mkdir(parents=True, exist_ok=True)

# --- RESUME LOGIC ---
processed_track_ids = set()
for f in BATCH_DIR.glob('results_batch_*.parquet'):
    try:
        chunk_df = pd.read_parquet(f, columns=['track_id'])
        processed_track_ids.update(chunk_df['track_id'].astype(str).tolist())
    except:
        pass

df_test['track_id'] = df_test['track_id'].astype(str)
remaining_tracks = df_test[~df_test['track_id'].isin(processed_track_ids)].reset_index(drop=True)
print(f"Found {len(processed_track_ids)} already processed tracks.")
print(f"Remaining tracks to process: {len(remaining_tracks)}")
# --------------------

new_results = []
total_processed = 0

# Instead of fetching everything at once, we chunk it into BATCH_SIZE
for batch_idx in range(0, len(remaining_tracks), BATCH_SIZE):
    batch_df = remaining_tracks.iloc[batch_idx:batch_idx+BATCH_SIZE]
    batch_results = []
    
    for _, row in batch_df.iterrows():
        tid = row['track_id']
        tname = row['track_name']
        
        streams = get_streams_kworb(tid, tname)
        batch_results.append({'track_id': tid, 'stream_count': streams})
        print(f"{tname[:40].ljust(40)} -> {streams}")
        
        time.sleep(0.1) # Be polite to Kworb
        
    # Save batch to disk
    if batch_results:
        batch_out_df = pd.DataFrame(batch_results)
        # Calculate correct batch index based on existing files to avoid overwriting
        existing_files = len(list(BATCH_DIR.glob('results_batch_*.parquet')))
        batch_file = BATCH_DIR / f'results_batch_{existing_files + 1:04d}.parquet'
        batch_out_df.to_parquet(batch_file, index=False)
        print(f"--- Saved {len(batch_out_df)} records to {batch_file} ---")
    
    new_results.extend(batch_results)
    total_processed += len(batch_results)
    
print(f"\nProcessing complete. Extracted {total_processed} new tracks.")
# Out:
# Found 16000 already processed tracks.
# Remaining tracks to process: 14000
# Sosa                                     -> 14753530
# When we danced                           -> None
# Fever                                    -> 139326306
# All The Things She Said                  -> 58737513
# closure                                  -> 156346409
# Drinking Class                           -> 155783845
# Save It for a Rainy Day                  -> 89627984
# Drink to That All Night                  -> 120933193
# Kontrol                                  -> 147277862
# Ragweed                                  -> 81177707
# Invisible - Piano Version                -> 39854304
# Go Robot                                 -> 121964461
# Jenny                                    -> 135576447
# Team                                     -> 156962056
# justified                                -> 58860195
# La Cita                                  -> 118490875
# Victory Lap (feat. Stacy Barthe)         -> 97511089
# 7 Am Freestyle                           -> 72623945
# éternité                               -> None
# Affection                                -> None
# We Own the Night                         -> 85722123
# Do Or Die                                -> 30063865
# Setting the World On Fire (with P!NK)    -> 116233531
# Saltwater Gospel                         -> 71873105
# Ice T                                    -> 34730070
# Butterflies Pt. 2                        -> 112822920
# Unaccompanied Cello Suite No. 1 in G maj -> None
# 再会 (produced by Ayase)                   -> None
# Highway 20 Ride                          -> 92920734
# Lonely East Texas Nights                 -> 114605128
# Throw It Back (feat. Keith Urban)        -> 85496811
# Pickup                                   -> 50940882
# Chicago                                  -> 99738260
# Nostalgia                                -> None
# Path Of The Warrior (Defqon.1 2023 Anthe -> None
# Rich Girl                                -> 79252339
# Çünkü Başka Sen Yok                      -> None
# french inhale                            -> None
# i'm in love with u, sorry                -> 79395582
# Shark Smile - Edit                       -> 79760885
# Please Never Fall in Love Again          -> None
# Hablar de Ti                             -> 128124368
# I Run To You                             -> 90976949
# california world                         -> 66783164
# the song they played (when i crashed int -> 71095764
# driveway                                 -> 67084522
# fucked up                                -> 52854774
# Boots On                                 -> 59694880
# PROBLEMZ                                 -> 61866463
# Niobe                                    -> 13971712
# Caméléon                                 -> None
# All In My Head (Flex) (feat. Fetty Wap)  -> 400372170
# A Whole New World                        -> None
# She's a Lover                            -> 35765316
# Start Again (feat. Logic)                -> 197422814
# A Dream Is a Wish Your Heart Makes       -> None
# Pula no Boiadeiro                        -> None
# Sky High                                 -> 81074878
# Origami Age                              -> 26652856
# Mind                                     -> None
# Gan Duille                               -> None
# Quite Buttery                            -> None
# Simien                                   -> None
# Pause                                    -> None
# Grace Kelly                              -> 530929512
# God Knows I Tried                        -> 71059400
# fall asleep                              -> None
# Old Downtown                             -> None
# reprise                                  -> 36572229
# Just One Yesterday                       -> 149080438
# The Beginning                            -> 145337234
# Line Of Sight (feat. WYNNE & Mansionair) -> 144640814
# Higher Ground (feat. Naomi Wild)         -> 120044510
# Seasons (feat. Khalid)                   -> 151758909
# Te Cambie                                -> 12697654
# Same Boat                                -> 53279385
# Steal My Love                            -> 57651532
# Rainy Day                                -> 50247358
# Funeral Derangements                     -> 42424873
# Is This It                               -> 139059715
# I'm A Believer - Radio Edit              -> 361053968
# By Mistake                               -> 74903808
# Lonesome                                 -> 38040130
# Don't Hurt Yourself (feat. Jack White)   -> 87310791
# Freedom (feat. Kendrick Lamar)           -> 108511300
# Paradise                                 -> 50590950
# Não Me Sinto Mal Mais                    -> None
# Keep On Loving You                       -> 187244467
# Affection                                -> 176349409
# Aquí Todo Esta Bien                      -> None
# Edge Of Darkness                         -> 70971032
# Make Me Better                           -> 95628853
# Nobody's Perfect                         -> 101804596
# Tattoo                                   -> 172669813
# Getting Along                            -> 48933229
# Circle The Drain                         -> 35960431
# Conversation Pt. 1                       -> 82786772
# Tu Cuerpo Me Llama Rmx                   -> None
# Kill Rock 'n Roll                        -> 102209433
# Söyleyin                                 -> None
# --- Saved 100 records to batch_results_streams/results_batch_0161.parquet ---
# Cesaretin Var mı Aşka                    -> None
# Come Together                            -> 128276390
# Tal Vez Quizas                           -> 94667478
# Meant 2 Be                               -> 32031264
# paradise                                 -> None
# Ζ. Kietu                                 -> None
# Mobali                                   -> 107856048
# Allez dehors                             -> 29844635
# Las cosas pequeñitas                     -> None
# Magnum                                   -> 16219703
# ALAKAZAM                                 -> 24928820
# Vem Me Dando (Pepekando)                 -> 21743544
# Ámame Hasta Con Los Dientes              -> None
# Somebody Told Me                         -> 75157217
# Carry On                                 -> 53102031
# O Grave Bater                            -> 161320903
# Mad About You                            -> 73444733
# C'Mon                                    -> 119987193
# You Can Buy Everything                   -> 115014369
# Last Hope                                -> 99266541
# Cosas De La Clika                        -> 49026969
# Better Days                              -> 64986885
# Face To Face                             -> 99752473
# This Love                                -> 60604273
# Astronaut In The Ocean                   -> 64993610
# Elevate                                  -> 179871756
# September - from DreamWorks Animation's  -> 107270854
# Venom - Remix                            -> 47837957
# S&M Remix                                -> 1623121006
# Mi Balcon                                -> 84226355
# A Little Too Much                        -> 224356293
# Mingo                                    -> 56744907
# BOY BYE                                  -> 102423551
# How Deep Is Your Love                    -> 63365790
# vibe                                     -> 18763992
# Hot                                      -> 90172814
# Ven Espíritu Ven                         -> None
# Solo Dance                               -> 831716355
# 9PM Frankfurter Tor                      -> 43805884
# Flasche Luft                             -> 73200733
# Hot Blood                                -> 99765555
# Confetti (feat. Saweetie)                -> 92058517
# 一路向北                                     -> None
# Last Christmas - Remastered              -> 2213435745
# Genkidama                                -> 30558790
# Hier encore - A COLORS SHOW              -> None
# 끝나지 않을 이야기                               -> None
# Pressure                                 -> 3584403
# Uncomfortable                            -> 63230373
# Slow Ride                                -> 56901251
# The Day You Went Away                    -> 93594005
# Shalala Lala                             -> 84176009
# Easter Sunday                            -> 32207017
# Girls Love Beyoncé (feat. James Fauntler -> None
# Better Days                              -> None
# Liquor                                   -> 119185133
# Break the Ice                            -> 100163686
# Home Body (feat. Gunna & TK Kravitz)     -> 100640071
# Feel The Love                            -> 141401194
# RADW                                     -> 104719827
# Not Sad Anymore                          -> 35511980
# Genghis Khan                             -> 178152034
# Ordentlich                               -> 73442451
# XXL                                      -> 93589674
# This Is Why                              -> 116364756
# Eye Spy                                  -> 18037704
# All in My Head                           -> None
# My Neck, My Back (Lick It)               -> 179086357
# The Feeling                              -> 269046374
# You Played Me (Interlude)                -> 13256159
# Quer Fuder Com os Sem Amor Vs Beat Risad -> None
# Followers                                -> 38498173
# Disconnected                             -> 39022133
# Somethin’ Country                        -> None
# Rednecks, Red Letters, Red Dirt          -> 75148885
# Wild Hearts                              -> 45754296
# Killshot - Slowed + Reverb               -> 164813025
# 닐리리맘보                                    -> None
# BLICK UNTERS DIRNDL                      -> None
# //aguardiente y limón %ᵕ‿‿ᵕ%             -> None
# Moonwalking in Calabasas                 -> 384172960
# Isis                                     -> 421017880
# Spectrum                                 -> 162733165
# Rang Jo Lagyo                            -> 72943351
# Love Myself - KREAM Remix                -> 720687521
# Good Nights (feat. Mascolo)              -> 148100375
# Sei Que Tu Gosta Muito                   -> 54801865
# Canarinho Prisioneiro - Ao Vivo          -> 71326835
# Trying                                   -> 29746925
# Tú Llegaste, Cuando Menos Te Esperaba    -> None
# 楓                                        -> None
# Libre                                    -> None
# Losing It - Radio Edit                   -> 643695078
# Mexico                                   -> 89047369
# Ghosts 'n' Stuff (feat. Rob Swire)       -> 39900211
# Wandering Child                          -> 84867019
# Rolling Stone                            -> 23229133
# Iniciales AL (Porte Fino)                -> 65192608
# Fazer Falta                              -> 232694507
# Lady by the Sea                          -> 38129080
# --- Saved 100 records to batch_results_streams/results_batch_0162.parquet ---
# Evenstar                                 -> 60511363
# No Place                                 -> 132140247
# U                                        -> 59528103
# It Don’t Matter - Spotify Singles        -> None
# Uh-Oh                                    -> 744953
# Inochi No Tabekata                       -> 47618393
# Wings                                    -> 41225643
# Used to Be in Love                       -> 126213366
# Snapping                                 -> 107526311
# Senorita                                 -> 95489998
# Nadie Te Amará Como Yo (Remix) (feat. Zi -> None
# Omo                                      -> 48049560
# Inner Smile                              -> 93417830
# War                                      -> 39452044
# Pobre de Ti                              -> 72571175
# Fusil                                    -> 82946787
# The Return                               -> None
# Sloopkogel                               -> 5156211
# Beer Don’t                               -> None
# Diri Diri (feat. Jory)                   -> None
# Sunshine (The Light)                     -> 94829963
# The Flute Song                           -> 139143997
# She Cheated Again                        -> None
# Turn My Swag On                          -> 109969215
# Love Drought                             -> 101874630
# KILLING ME                               -> 138847413
# Violeta                                  -> 89407965
# One, Two, Three, GO!                     -> 53347503
# Nails, Hair, Hips, Heels                 -> 116340625
# Come Together (feat. H.E.R.)             -> 78806080
# Aventura Noturna                         -> 86872031
# Baby Birkin                              -> 154091501
# Pesetas                                  -> 119389426
# Rocket Ship                              -> 41862596
# Crushed Up                               -> 139506793
# DRAINO (feat. Denzel Curry)              -> 54369965
# Have Mercy                               -> 140040505
# Bora Bora                                -> 67645152
# Let It Go - James Bay Spotify Session 20 -> 1386830489
# Sesame Syrup                             -> 168582822
# In Love                                  -> 97584872
# You Should've Known                      -> 75015122
# Mia Mia                                  -> 39863697
# My Only Wish (This Year)                 -> 454452225
# Miracle In The Middle Of My Heart        -> None
# Starships                                -> 1537111071
# Work Hard, Play Hard                     -> 210602469
# Watermelon Meow Meow                     -> None
# buzzkill                                 -> 59000895
# Work Out                                 -> 25511174
# Silencio En El Callejon                  -> None
# Just Wanna Be With You                   -> 112983455
# Funhouse                                 -> 125560258
# Daft Pretty Boys                         -> 127634299
# The Four Seasons - Violin Concerto in F  -> 53612547
# Real Life                                -> 145632180
# Sunflower Seeds                          -> 56525362
# Como Quien Pierde una Estrella           -> 247655146
# Gum Body (feat. Jorja Smith)             -> 101938554
# Putuskan Saja Pacarmu                    -> 37689102
# Hum Mar Jayenge                          -> 90008415
# Me & You ◑                               -> None
# Tose Naina                               -> 155530676
# Scars leave beautiful trace              -> 21175835
# De Qué Manera Te Olvido                  -> None
# Too Late                                 -> 43900511
# u turn me on (but u give me depression)  -> 33764196
# Bad Day                                  -> 30135378
# WE MADE PLANS & GOD LAUGHED              -> 15308052
# Booska'Triste Fête                       -> None
# Butterfly - Prologue Mix                 -> 1437131709
# Galaxy 우주를 줄게                            -> 78735740
# Rough                                    -> 90630888
# I Stay In Love                           -> 55177342
# Beat Lázaro Talarico 2                   -> None
# Ligou na Madruga                         -> 88059702
# The King                                 -> 85877130
# Leave A Little Love                      -> 106310559
# My Head & My Heart - Claptone Remix      -> 620242416
# Selfish Love (with Selena Gomez)         -> 122237584
# Floatin'                                 -> None
# DYING 4 YOUR LOVE                        -> 67050683
# Lo Hecho Está Hecho                      -> None
# Purple Nights                            -> None
# My Friend                                -> 80115601
# Wait for the Moment                      -> 77861462
# Ladies Night - Single Version            -> 95417488
# Unterwegs                                -> 122801705
# Dudu                                     -> 93139322
# Después De Ti                            -> None
# Say It (feat. Tove Lo)                   -> 434243377
# BO$$ CHICK                               -> 13880158
# you up?                                  -> 81943275
# Shake It Off                             -> 164782820
# What Do They Know?                       -> 110752561
# Shut Me Up                               -> 190161831
# Welcome Home                             -> 413839890
# Precious                                 -> 182412208
# Is It True                               -> None
# Liquorice                                -> 59781538
# --- Saved 100 records to batch_results_streams/results_batch_0163.parquet ---
# Bonfire                                  -> 145098316
# Certo Pelo Duvidoso - Ao Vivo            -> 9502690
# Die Nacht von Freitag auf Montag         -> 55410919
# Uyirin Uyire                             -> 52270376
# INDICE                                   -> 19417688
# After A Few                              -> 81357242
# Blessings                                -> 91399386
# Henry V: Henry V: Touch her soft lips an -> None
# Orfeo ed Euridice, Wq. 30 (Arranged by S -> None
# Xion                                     -> 24183687
# San Frandisco                            -> 109630103
# Sentadinha Descarada                     -> 39251096
# Never Be Alone                           -> 392438782
# Clouds                                   -> 66886087
# Screaming Suicide                        -> 50921753
# It's Our Love                            -> 68694292
# My Dil Goes Mmmm                         -> 84061078
# Paper Cuts                               -> 56256604
# It Might Be You                          -> 81369042
# Florida Rain Storm                       -> None
# Death Cup                                -> 98654647
# Snap Shoot                               -> 53150942
# Impossible (feat. John Martin)           -> 54902920
# Vou falar que não quero                  -> None
# Passatempo                               -> 124794521
# Hope Not                                 -> 138399491
# Silence - DJ Tiësto's In Search Of Sunri -> 13174105
# AA                                       -> 98917159
# La Melodía                               -> None
# I Really Wish I Hated You                -> 72874357
# veil                                     -> 117702661
# Un'emozione per sempre                   -> 67289035
# Mais Amor E Menos Drama - Ao Vivo        -> 218421374
# Apelido Carinhoso                        -> 211327822
# Amor Da Sua Cama                         -> 184095628
# Flying Whales                            -> 79009387
# Wifey Riddim                             -> 52180764
# i need to be alone.                      -> 93419237
# Potential Breakup Song                   -> 200446343
# Changes                                  -> 51811353
# Dirt Road                                -> 76202301
# Do Pal                                   -> 58417306
# LIKE A ROCKSTAR                          -> 57548370
# Tissues                                  -> 46838853
# Ee Raathale (From "Radhe Shyam")         -> 61559373
# Can't Lie                                -> 138310273
# Pure White Noise Only (Non Stop Loop)    -> None
# nothing but the love                     -> 22096120
# High (feat. Apache)                      -> 112444024
# Roke Na Ruke Naina                       -> 144463744
# You Make Me Feel Like It’s Halloween     -> None
# Getaway - Koven Remix                    -> 50393432
# Clap Back                                -> 78071232
# Reindeer(s) Are Better Than People - Fro -> 104734926
# Love You Like That                       -> 167043273
# Sweater Weather                          -> 107884983
# Pills N Potions                          -> 275815493
# Billets verts                            -> 106031092
# Madrina                                  -> 141665111
# Pretender                                -> 312455320
# At the End of a Bar                      -> 50825003
# By Your Grace                            -> 44727322
# Rise & Fall (feat. Sting)                -> 81294406
# I Am the Antichrist to You               -> 57582734
# Karpurgauram                             -> 30786653
# Amante Não Tem Lar - Ao Vivo             -> None
# Christmas Tree Farm                      -> 287915798
# This Is Real (ft. Ella Henderson)        -> 137301913
# Sweet but Psycho - Morgan Page Dance Rem -> 2034150444
# Carried Me With You                      -> None
# You Were                                 -> None
# Helsinki                                 -> 58856906
# Nuit                                     -> 67050614
# M.I.L.S 2.0                              -> 96546955
# Todos Tenemos Un Amor                    -> 72989210
# La Que Se Fue                            -> 97511189
# Wildfire                                 -> 131639951
# Love Me Like a Friend                    -> 32499983
# Take My Breath Away                      -> None
# All Goes Wrong                           -> 82772977
# I'm Happy                                -> 17722589
# Younger                                  -> 19180559
# Abandon - Mix Cut                        -> None
# The Way You Look Tonight                 -> 94342928
# Holly Jolly Christmas                    -> 900455572
# Man Don't Care                           -> 130102106
# Dream of you                             -> None
# Redneck Love Song                        -> 67084507
# Follow You to Virgie (Live)              -> 49005452
# I Wanna Dance With Somebody - Who Loves  -> None
# Lean Wit It, Rock Wit It                 -> 82825909
# Stuntin' Like My Daddy - Street          -> 91518843
# Sur ma route                             -> 100386955
# Ain't Far From It                        -> 18334041
# World Spins Madly On                     -> 76977128
# Aceptas                                  -> 60183361
# El Ritmo No Perdona - Bonus Track        -> 63221092
# As You Leave (undone)                    -> 25196380
# Crushed                                  -> 20127720
# On My Mind                               -> 335170044
# --- Saved 100 records to batch_results_streams/results_batch_0164.parquet ---
# papercuts                                -> 75306239
# ...The Make Up                           -> 40424397
# Batmóvil - Remix                         -> None
# Rafa Caro                                -> 123405478
# Hot Shower                               -> 218433656
# Baby                                     -> 707873009
# Sientes Lo Que Siento                    -> 202732019
# Subtitle                                 -> 217642068
# House of Memories - Sped Up Version      -> 966022678
# Compliance                               -> 40474753
# Ngã Tư Không Đèn                         -> None
# That's Why                               -> 23580592
# The First Soldier                        -> 12959700
# Genda Phool                              -> 59098072
# ¿Qué Se Siente Que Me Gustes Tanto?      -> None
# Ahora Dice - Real Hasta La Muerte Remix  -> 832363323
# Paris                                    -> 36355033
# Stay                                     -> 149961328
# Estrellas                                -> 53922156
# Selfish                                  -> 32990329
# Drowns The Whiskey (feat. Miranda Lamber -> None
# Heart of Gold                            -> 48159545
# coffee                                   -> 177087001
# I Don't Miss You at All                  -> 74840787
# Cold                                     -> 92985085
# go with u                                -> 84142244
# Maus Bocados - Ao Vivo                   -> 7749715
# Whine & Kotch                            -> 128991240
# Daydreamin' (feat. Jill Scott)           -> 100526447
# A Whole New World (End Title)            -> 380827611
# Hold My Halo                             -> 22760634
# New Rules                                -> 63897609
# Growing Old With You                     -> 49502176
# Worst Day                                -> 17926544
# See Through                              -> 71784754
# Kiss Somebody                            -> 170158710
# Here Tonight                             -> 125132236
# Caught Up In The Country                 -> 328495861
# Meri Aashiqui                            -> 95443274
# あなぐらぐらし                                  -> None
# Living                                   -> 121678200
# Ciao Ciao                                -> 63103374
# Drifting Away                            -> 15732827
# Changes                                  -> 13233340
# Like Her Too                             -> 13281562
# Shivering                                -> 28975868
# 勿忘                                       -> None
# Technicolour Beat                        -> 151669113
# Girls Like Girls                         -> 149177450
# Happy & Sad                              -> 74578837
# Was It Something I Said                  -> None
# Para Aute: Pasaba por Aquí (feat. Abel P -> None
# Sur Paname                               -> 75072537
# Den här gången är det på riktigt         -> None
# There's Still A Light In The House       -> 58564105
# La La Land                               -> 254914499
# Ang Huling El Bimbo                      -> 194702973
# Ligaya                                   -> 142263722
# Sweetie Little Jean                      -> 71380139
# FXXK IT                                  -> 158460495
# Somewhere Only We Know - BBC Steve Lamac -> 2456133325
# Sirena                                   -> 206636698
# I Can't Love You Anymore                 -> 20167961
# Se Me Va La Voz                          -> 100367889
# Another Day in Paradise                  -> 133143155
# Dream Girl                               -> 353233388
# Disco Inferno - Edit                     -> 172984345
# Que Calor (feat. J Balvin & El Alfa)     -> None
# Un beso de improviso                     -> 52807844
# Quando Tá Com Ela                        -> None
# Ficamento - Ao Vivo                      -> 42876497
# Saudade Louca - Ao Vivo                  -> 11365689
# The Motion                               -> 155201046
# altar                                    -> 55681411
# Let You Go                               -> 49689608
# Build God, Then We'll Talk               -> 153088533
# Butterflies                              -> 61311342
# Son Of The Dirty South                   -> 74746937
# Video Killed The Radio Star - Single Ver -> 468857170
# Without You                              -> None
# Edge of Desire                           -> 104766506
# Cuéntale                                 -> None
# Moriré                                   -> None
# Oye                                      -> 8234364
# Faded                                    -> 378467855
# Una en un Millón                         -> None
# Johnny Däpp (Ich will Mallorca zurück)   -> None
# Llueve sobre mojado                      -> 66310811
# Let Me Go                                -> 87816880
# Escape - John Summit Remix               -> 35140140
# Locura                                   -> 181091471
# APESHIT                                  -> 324154109
# Pras Novinha (feat. DJ Pedrin)           -> 33148096
# No Podras Escapar De Mi                  -> 64222485
# Quiero Morir En Tu Piel                  -> 140344533
# Hazme Olvidarla                          -> 131207938
# Due tramonti                             -> 28442420
# Mean It                                  -> 54165223
# World so Cold                            -> 93902709
# Rome Wasn't Built in a Day               -> 69051270
# --- Saved 100 records to batch_results_streams/results_batch_0165.parquet ---
# Odd Look                                 -> 105428282
# A Little Party Never Killed Nobody (All  -> 287379138
# The Other Side                           -> 303331316
# You'll Be in My Heart                    -> 37172295
# Hymn Of Heaven                           -> 47301852
# Strings                                  -> None
# 34.0522° N                               -> None
# La Costa                                 -> 55771332
# No Me Arrepiento de Este Amor            -> 128448663
# Affection                                -> 34721357
# Money Spent                              -> 20342505
# Impossible                               -> None
# Don't Walk Away                          -> None
# Dance Tonight                            -> 30388904
# Wait                                     -> 517921801
# Fuck You and All Your Friends            -> 44311717
# Play My Music                            -> 99721670
# Matar la Pena                            -> 37235143
# De Perreo                                -> 41603613
# How He Loves                             -> 97363536
# Get Stoned                               -> 97048426
# That Kind Of Woman                       -> 55809256
# El Carnaval                              -> 61389895
# One Of Us                                -> 12837656
# On The Low                               -> 19386523
# Softly                                   -> 28949535
# Invisible - Paul Kalkbrenner Remix       -> 43844769
# To Be Alone With You                     -> 124685238
# In Betweenin'                            -> None
# talk                                     -> 34781592
# Free Spirit                              -> 182043493
# Summer Time High Time                    -> 100212922
# Borrowed Time                            -> 82050650
# Unbothered                               -> None
# 21                                       -> 51773464
# Mômes                                    -> None
# Hurt From Mercury                        -> 39760045
# This Is How We Do                        -> 300751972
# Last Christmas                           -> 326218930
# Check My Brain                           -> 98297553
# TOO LATE                                 -> 46134611
# Viajando en una Nube                     -> 42385614
# Still Ballin' - Nitty Remix              -> 54902279
# Better Dayz                              -> 68729346
# High Right Now                           -> 142323301
# Everywhere (BBC Children In Need)        -> 53401417
# 13 Missed Calls                          -> None
# Fume à fond                              -> None
# Venus                                    -> 105438173
# Hello Kitty                              -> 78391103
# Mad About You                            -> 89216692
# Bags                                     -> 55283002
# Get Low                                  -> 218736035
# SELF PROCLAIMED 2                        -> None
# WATER. - Quarterhead Remix               -> 17153683
# Kahit Pa                                 -> 71215529
# Embody Me                                -> 45631021
# Biomes                                   -> 32516953
# Lose Your Love (with Matt Maeson)        -> 14183454
# Strawberries and Wine - Acoustic         -> None
# Cocaine Model                            -> 135817886
# Catch Me If You Can                      -> 15239949
# Hello World                              -> 48636283
# What Dreams Are Made Of                  -> 55800012
# Stardust Chords                          -> 31270401
# I Wish You Love                          -> 144463297
# Everybody Loves Me                       -> 79384550
# Ready Yet                                -> 22103821
# Deli                                     -> 48768172
# Where You Belong                         -> 41833482
# Of The Night                             -> 201092581
# Frío, Frío - En Vivo Estadio Olímpico De -> None
# La danse des bandits                     -> 80817115
# Le classico organisé                     -> None
# Losar                                    -> 34019759
# Judas                                    -> 84646634
# Waitin' On A Sunny Day                   -> 67711706
# Maze                                     -> 19704877
# Outnumbered - Acoustic                   -> 365865603
# Right Back                               -> 163538366
# What If I Wasn't Done Loving You?        -> 27066740
# the way that we started (taylor)         -> 19748354
# Ghost                                    -> 41407489
# I'll Be There For You/You're All I Need  -> 103186812
# No Le Temas A Él (feat. Héctor & Tito)   -> None
# PERIGO NOTURNO - Ao Vivo                 -> 40226129
# Eu Me Trai - Ao Vivo                     -> 28178342
# Last Minute                              -> 39084541
# No Quiere Enamorarse                     -> 163297467
# Bottom                                   -> 86319073
# Find Someone Like You                    -> 70222863
# Slow Hands - Acoustic                    -> 1068908331
# Can't Stop Loving You - 2016 Remaster    -> 115737720
# No Reason                                -> 74145446
# Pluto’s Last Comet                       -> None
# Ferida Curada                            -> 241822359
# A Gente Fez Amor - Ao Vivo               -> 238300862
# Beautiful Escape                         -> 114251060
# Beautiful Stranger                       -> 75937754
# To All The Boys I’ve Loved Before        -> None
# --- Saved 100 records to batch_results_streams/results_batch_0166.parquet ---
# Tout savoir                              -> 46635651
# Et alors ?                               -> 23298960
# W.T.P.                                   -> 123487375
# do u even miss me at all?                -> 197892221
# hello!                                   -> 50853666
# Loyal To The Game                        -> 62167880
# LA PASE                                  -> 23120027
# Contigo                                  -> 53837756
# El Dolor del Micro (feat. Julieta Venega -> 72850804
# Why iii Love The Moon.                   -> 95990840
# Verdes Verdes                            -> 65680686
# Avisa Lá, Pt.3                           -> None
# Ring My Bell                             -> 88227331
# 92i veyron                               -> 137471107
# Mão Boba                                 -> None
# FIRST                                    -> 63969217
# Scars                                    -> 49300129
# Quiza Llevarte                           -> 40846951
# No Place I Call Home                     -> 16610588
# Not Angry                                -> 43593899
# Surrender My Heart                       -> 15973772
# Woke up in Bangkok                       -> 113844528
# Heaven Knows - This Angel Has Flown      -> 263960790
# TAIL                                     -> 56456386
# don't stay awake for too long            -> None
# Let Me Know                              -> 29856440
# Soul Meets Body                          -> 159540799
# Bombs Away (Throwback Cypher)            -> 36862427
# It's My Life                             -> 219002620
# Right Now                                -> 113756773
# Pet                                      -> 71322164
# Turbulence                               -> 40817609
# 2023                                     -> 9173245
# Love Abuser (Save Me)                    -> None
# I Think I'm Growing?                     -> 14558511
# Swoosh                                   -> None
# Sofridas por Minuto - Ao Vivo            -> 32222393
# Lucky                                    -> 29044927
# KILL SH!T TILL I DIE                     -> 13951564
# Dig                                      -> 15310742
# Unlove You                               -> 11863853
# Diggy Diggy Hole                         -> 88092613
# I Was Sad Last Night I'm OK Now          -> 74151141
# 空に歌えば                                    -> None
# The Devil's Calling                      -> 23294869
# Opulent                                  -> 19977087
# Watching Airplanes                       -> 98231522
# All About That Bass                      -> 949289338
# Sem Essa de Perder                       -> 29155253
# Where You Are - From "Moana"/Soundtrack  -> 414982665
# Come Clean                               -> 87926975
# When I'm Down                            -> 126465833
# There, There                             -> 83536320
# 2 + 2 = 5                                -> 78052527
# HELLO (NAYEON, MOMO, CHAEYOUNG)          -> 34861227
# The View                                 -> 45663952
# Other Half                               -> 16888305
# Kokoronashi                              -> None
# Todavia Me Amas                          -> 205954492
# novio del año                            -> None
# Where To Start                           -> 44404502
# Nit Nit                                  -> 52582348
# Que Sera                                 -> 100572125
# We Are Mirage                            -> 96514431
# Unchained Melody                         -> None
# Bottom Bitch                             -> 94721791
# Superfast Jellyfish (feat. Gruff Rhys an -> 81595057
# Cold Wind Blows                          -> 121689195
# Mi Ultima Carta                          -> 91590994
# WOLFGANG                                 -> 69135188
# Goner                                    -> 186212383
# If I Didn't Have You                     -> 61362719
# Will You Still Love Me Tomorrow? - 2011  -> 121663933
# Believer - Marsh's Guatape Remix         -> 17578461
# Long Nights                              -> 87952984
# Elemental                                -> 32363864
# Just a Boy                               -> 37369138
# Carnaval, Op. 9: No. 12. Chopin          -> None
# Legendary                                -> 105604600
# Sunrise                                  -> 65303984
# Quero Você do Jeito Que Quiser           -> None
# DUMB DUMB                                -> 177346203
# Tell Me The Truth                        -> 26795662
# Stockholm Syndrome                       -> 101222043
# Sticker                                  -> 72712630
# LAST WALTZ                               -> 37800186
# XOXO                                     -> 130709110
# I Wouldn't Mind                          -> 162354527
# Ain't It Funny (feat. Ja Rule & Cadillac -> 59442274
# Little Things                            -> 88802693
# Needles                                  -> 87288487
# Psycho                                   -> 110621772
# Cheirosa - Ao Vivo                       -> 226287002
# Jigga What / Faint                       -> 62345365
# tired of california                      -> 32847249
# PMW (All I Really Need) (feat. ScHoolboy -> 138737683
# Ghetto Symphony (feat. Gunplay & A$AP Fe -> 103733113
# Oh Quão Lindo Esse Nome É                -> None
# Yeshua                                   -> 77789945
# Angeklagt                                -> 126004504
# --- Saved 100 records to batch_results_streams/results_batch_0167.parquet ---
# Simple Man - Rock Version                -> 83175239
# Soda                                     -> 52823255
# Sappy                                    -> 48972680
# Open                                     -> 144023780
# You've Got My Number                     -> 9675469
# Short Fuse                               -> 16302947
# Tainted Love                             -> 33117429
# La pachanga                              -> 233315279
# Traidora (feat. Marc Anthony)            -> 158277659
# Iron                                     -> 107106548
# Wallflower                               -> 29991957
# U - English Version                      -> 59528103
# Forces of Attraction                     -> 48526426
# Deep Inside                              -> 26604407
# Domestic Pressures                       -> 51560222
# Camping                                  -> 54672031
# Window                                   -> 169104208
# Sunlight (feat. Years & Years) - Radio E -> None
# Black Converse                           -> 33964831
# Love Like This                           -> 76599900
# Dreams Unfold                            -> 60190455
# Bitch Came Back                          -> 116317328
# Internet Ruined Me                       -> 85237040
# It Won't Hurt                            -> None
# Hour of Rest                             -> None
# Dirt off Your Shoulder / Lying From You  -> 156095285
# Devolve                                  -> 20477403
# Não Gosto Eu Amo - Ao Vivo               -> None
# Addicted                                 -> 118768398
# Sans Regrets                             -> None
# Miss Me                                  -> 115352973
# Where The Skies Are Blue                 -> 105286108
# Breathing                                -> 22415480
# Sad Boy (feat. Ava Max & Kylie Cantrall) -> 51097354
# Las Demás                                -> None
# Wherever You Go                          -> 38542938
# Você Consegue Sim                        -> None
# Riptide                                  -> 37313293
# aisatsana [102]                          -> 79465166
# Help Is On The Way                       -> 89883035
# Lose You                                 -> 12227438
# The Logical Song - Radio Edit [Remastere -> 201952991
# move                                     -> 27237217
# Steeeam                                  -> 157104801
# Photo ID                                 -> 121083949
# Love Me Now (feat. FAST BOY)             -> 30549611
# Gasoline                                 -> 70613156
# Whenever (feat. Conor Maynard)           -> 355058115
# Far Away Place - Rampa Remix             -> 51293918
# Reflections                              -> 12460774
# Dear Agony                               -> 94131971
# Earthquake (feat. Tinie Tempah)          -> 123104086
# Live For                                 -> 17581921
# El Rey De Mil Coronas - Live             -> None
# This Is Love                             -> 168111448
# Blind Fold                               -> 13007664
# Pink Noise For Sleep 4                   -> None
# Returns                                  -> 84012213
# Producer Man                             -> 53899084
# 2econd 2ight 2eer (that was fun, goodbye -> 44639735
# Monolithic                               -> 23550833
# Se For Passar Em Goiânia - Ao Vivo       -> None
# Comin’ In Hot                            -> None
# GO STUPID                                -> 31576837
# Soy Mencho                               -> 60164596
# Younger Now                              -> 99558002
# Counting Days Till Suicide               -> 34910218
# Love It When You Hate Me (feat. blackbea -> 57916272
# So Young                                 -> 122235413
# Never Going Back                         -> 63379370
# I Don't Wanna Know                       -> 19020592
# Retro Emporium                           -> 16298350
# Gerua (From "Dilwale")                   -> 108801896
# Sponono (feat. Baby S.O.N & 031 Choppa)  -> 2608493
# Maldita de Ex                            -> 127500100
# How Did You Love                         -> 90796665
# Hollywood Forever Cemetery Sings         -> 80993377
# Começo, Meio e Fim / Mais Perto Quero Es -> None
# Why you gotta lie?                       -> None
# Me Liberé                                -> None
# The Future                               -> 18145607
# Tomorrow                                 -> 105612016
# Ressuscita-me                            -> 95222343
# Hide Away                                -> 31935838
# Hopelessly Devoted To You - Remastered 2 -> 734540
# Was für eine geile Zeit - Single Mix     -> None
# LSD                                      -> 29834360
# Bir Ateşe Attın Beni                     -> None
# ilomilo                                  -> 50835110
# Hey Now - When I Give You All My Lovin'  -> 65622076
# Blueberry Yum Yum                        -> 94070821
# Ghostwriter                              -> 113272319
# Pretty Girl                              -> None
# Syrener                                  -> 55105462
# Champion                                 -> 56156148
# Siragugal                                -> 56975918
# GOOD BOY                                 -> 123056287
# Miniskirt                                -> 158470534
# Still                                    -> 35468054
# If I Ever Leave This World Alive         -> 60608403
# --- Saved 100 records to batch_results_streams/results_batch_0168.parquet ---
# Calm Down                                -> 11500666
# Bad Reputation (feat. Joe Janiak)        -> 85848501
# Don't Call Me Up - R3HAB Remix           -> 1125612946
# sushi for breakfast                      -> None
# for lovers who hesitate                  -> 59102832
# DDU-DU DDU-DU - Japanese Version         -> 852829902
# What Can I Do                            -> 17749916
# Abigail                                  -> 20253699
# Everything To Everyone (Intro)           -> 15503685
# What A Difference A Day Made             -> 68101732
# Street Fight                             -> 48380643
# Abhi Kuch Dino Se                        -> 120998814
# Sajde                                    -> 78483281
# Make Me Your Queen                       -> 67809072
# Going Dumb                               -> 81831081
# One Way (feat. T-Pain) - Bonus           -> 90779341
# CIGARETTES                               -> 66057544
# Marvelous                                -> 22367832
# FUCK ABOUT IT (feat. blackbear)          -> 21497291
# Breakdown                                -> 69402342
# sweet sweet                              -> 141196870
# coordinate                               -> 153349266
# A-Team                                   -> 126161845
# Trapper Of The Year (Intro) - Bonus Trac -> 34273749
# This Feeling                             -> 64184917
# your love                                -> 25799787
# Samma gamla vanliga                      -> 85206912
# Believer (feat. Lil Wayne)               -> 3779545097
# Money                                    -> 74634685
# One Foot                                 -> 144025407
# Glorious Day - Live                      -> 100901564
# Everybody Gets High                      -> 92417014
# The Fall                                 -> 82589345
# Electric - Pokemon 25 Version            -> 68931363
# Going Dumb (with Stray Kids)             -> 81831081
# Talia                                    -> 136995679
# HaifischNikez Allstars                   -> 92053101
# SENTADÃO                                 -> None
# Drunk On A Flight                        -> 9954554
# Shiroyama                                -> 76353466
# Six Days - Remix                         -> 335247595
# Está Tudo Bem                            -> None
# Hino da Vitória                          -> None
# Brot nach Hause                          -> 79314520
# The Passenger (LaLaLa) [feat. MOKABY]    -> 143249422
# Moon                                     -> 24575187
# MustBeARealDragWakingUpAndBeingYou       -> 36830716
# 10 Feet Down                             -> 107431046
# Hannah (the sun)                         -> 48117310
# Wolfcat                                  -> 60228288
# Worried                                  -> 32924908
# Falling (feat. blackbear) - blackbear Re -> 1855010609
# XNXX                                     -> 77260094
# Frozen (feat. 070 Shake)                 -> 218267330
# Magical Doctor                           -> None
# Congratulations                          -> 75941624
# MANIFESTO (feat. Domo Genesis)           -> 64298305
# Swerve City                              -> 92484184
# Skeletons In My Closet                   -> 45519807
# Level Tipping Scales                     -> 23809220
# Dearly Beloved (feat. Jamie Foxx)        -> 21259515
# Fair                                     -> 33777893
# Guitar Gangsters & Cadillac Blood        -> 79341034
# Never Gonna Be Alone                     -> 113755891
# Hela huset                               -> 94437989
# Tausend Tattoos                          -> 157031003
# Tandtråd                                 -> None
# BDE Bonus                                -> 101529118
# Slim Pickens Does The Right Thing And Ri -> 54830288
# Pro Freak (with Doechii, Fatman Scoop)   -> 23683636
# StarShine (I Don't Want This Night To En -> 21624867
# Ready To Let Go                          -> 119993970
# Americana                                -> None
# Zombie (Zombic & Felix Schorn Remix)     -> 66504751
# N.O                                      -> 118594491
# Anemone                                  -> 91129939
# Déjale Caer To' El Peso (feat. Yomo)     -> None
# Café Con Leche                           -> None
# 쏘리 쏘리 Sorry, Sorry                       -> 1431216
# End Up                                   -> 19218980
# Love Runs Out (feat. G-Eazy & Sasha Alex -> 59243901
# Angel Dust                               -> 35025022
# too easy                                 -> 157482165
# 19 Somethin' - Greatest Hits Version     -> 63868103
# YOU AGAINST YOURSELF                     -> 21894041
# 976-EVIL                                 -> 57042724
# This Hell                                -> 44118573
# I'm Not Dead Yet                         -> 16193630
# van gogh                                 -> 9434117
# star tripping                            -> None
# Just To Keep You Satisfied               -> 11405988
# Ocean                                    -> 65731535
# Π. VANTABLACK                            -> None
# Dreams Tonite                            -> 123616786
# New To You (with Normani, Tinashe, & Off -> None
# American Psycho (with Mae Muller feat. T -> 19205843
# The Breakup Song (From "Ae Dil Hai Mushk -> 111741883
# Sarcophagus III                          -> 59574700
# dashstar*                                -> 59034892
# ...
# Dogs of War                              -> 29605095
# Don't Stay Gone Too Long                 -> 3701702
# A Dream of You and Me                    -> 56138023
# Nêga                                     -> None
# On My Mind                               -> 125422855
# The Real                                 -> 40524485
# THRILL RIDE                              -> 27387590
# Ito                                      -> 29410754
# What Type of X                           -> 49538909
# --- Saved 100 records to batch_results_streams/results_batch_0277.parquet ---
# Fallout                                  -> 68208082
# You're the Sea                           -> 8369914
# Rabbit Hole                              -> 8190623
# No, No                                   -> None
# Oversight                                -> None
# MURDA                                    -> 10822451
# Romeo                                    -> 35423632
# ¿Do U Wanna Leave?                       -> 13902103
# My Mind                                  -> 30022287
# Break My Stride                          -> 524788832
# Hackearam-Me                             -> 113625977
# Bis es kracht - Empyre One & Enerdizer E -> None
# PANG!                                    -> 22095463
# Threnody                                 -> 129675159
# Ice Cold (Final Round) (with Vince Stapl -> None
# Miss Atomic Bomb                         -> 87444557
# Mayday                                   -> 20058201
# Play Dumb                                -> 3310774
# Not Good But Better                      -> 10572411
# Quien Te Cantara                         -> 51985287
# Get It Crackin - Sefa Remix              -> None
# Traffic - Radio Edit                     -> 50752605
# Que Seas Mi Hogar (feat. Reyli Barba)    -> 24631282
# Soulful Strut                            -> 34522368
# Nadie Dijo                               -> 34974502
# Ciao Adios                               -> 361151632
# Hold Me Down                             -> 20381310
# Nothing Breaks Like a Heart - Acoustic V -> 29475656
# Ganja                                    -> 16371601
# Who You Are To Me (feat. Lady A)         -> 41042501
# Ohms                                     -> 51036131
# Late Night Feelings (feat. Lykke Li)     -> 121937511
# Pieces Of Me                             -> 98378808
# These Are The Days                       -> 24434891
# What Would You Do?                       -> 91789141
# El Tango De Roxanne - From "Moulin Rouge -> 84511622
# The Space Between                        -> 68347800
# Tous les mêmes                           -> None
# Bambi                                    -> 86112596
# Already Gone                             -> 31783566
# BALENCIAGA                               -> 60403415
# Magic City                               -> 40017419
# Cool                                     -> 147559323
# Rumors                                   -> 36812982
# Ceremony                                 -> 30248712
# Patience                                 -> 71632649
# Silver Lining                            -> 29749715
# Patrullando Voy                          -> 31828413
# Meu Universo                             -> 33681716
# SOHO                                     -> 101927625
# Better Than Me                           -> 31839434
# De Pies a Cabeza                         -> None
# Loving You                               -> 26589525
# Me Quedaré                               -> None
# i like red                               -> None
# Bleed Magic                              -> 38083541
# Love Moved First                         -> 23686381
# Falling Asleep                           -> 28366393
# No Impossible with You                   -> 26273781
# We Watch The Stars - Berlin Session      -> 25943551
# Heaven - DJ Isaac Remix                  -> 29980608
# Decline                                  -> 80025862
# Breathe It In                            -> 19967242
# Harder (with Bebe Rexha)                 -> 214649893
# Passport Home                            -> 85806730
# Going up the Coast                       -> None
# Over the Influence                       -> 26105337
# The Birthday Party                       -> 46982068
# Reaching                                 -> 5137117
# Out Of My Hands                          -> 23116427
# Waking Lions                             -> 71607340
# Just in Case                             -> 43387233
# Kyrie - Single Version                   -> 59379426
# En Su Lugar                              -> 60926023
# Float                                    -> 18446324
# Fame                                     -> 23138383
# Stepping Stone                           -> 126741257
# Do Like That                             -> 99936898
# There's A Place                          -> 15561556
# Worry No More                            -> 26173580
# Million To One - from the Amazon Origina -> 46953881
# 慢慢等                                      -> None
# I Forgot To Be Your Lover                -> 58452887
# The Gangsta, The Killa And The Dope Deal -> 102840141
# Mesajımı Almıştır O                      -> None
# Talk In The Morning                      -> 20980852
# 7empest                                  -> 53271334
# Wait and Bleed                           -> 624328862
# When You Wash Your Hair                  -> 16250827
# How Lucky                                -> 26981699
# sunday                                   -> 33339829
# Wading In Waist-High Water               -> 25965403
# I Can't Lose                             -> 22615756
# Feel Good (feat. Lil Tjay)               -> 21264271
# Maybe if                                 -> 30817394
# Witness                                  -> 30488976
# Are U gonna tell her? (feat. MC Zaac)    -> 49080362
# Dein Ex (feat. KC Rebell)                -> 56718101
# Je vous trouve un charme fou - En duo av -> 43198747
# Mundo Interior                           -> 23278550
# --- Saved 100 records to batch_results_streams/results_batch_0278.parquet ---
# A Estas Horas                            -> 62123429
# ANL                                      -> 31728314
# Officer of Love                          -> 46816024
# New Rules - KREAM Remix                  -> 2515832388
# All This Love                            -> 102561537
# No Confíes en Mí                         -> None
# Love Faces                               -> 75917127
# Sweet Dreams (Are Made Of This)          -> None
# Problem With You                         -> 680548052
# Let Me Love You - Tiësto's AFTR:HRS Mix  -> 2934028665
# HOW DARE YOU                             -> None
# Ukryty w Mieście Krzyk                   -> None
# Everyone And No One                      -> 5171289
# You Make Me Feel                         -> None
# I Do - Vandelux Remix                    -> 30562751
# Whole Heart (Hold Me Now) - Live         -> 120948912
# Make Us Never Happen                     -> 31368869
# Easier                                   -> 77899629
# Fête de trop                             -> None
# Body Talks                               -> 55518785
# Be My Fire                               -> 31016883
# Everything                               -> 58778877
# Time (feat. Snoh Aalegra)                -> 19811341
# Up to You (feat. NCT DREAM)              -> 36352148
# Bebe e Vem Me Procurar                   -> 126426743
# Self vs Self (feat. In Flames)           -> 50528112
# Darling                                  -> 34084296
# Diggity                                  -> 26044045
# On My Way                                -> 41957638
# A fleur de toi                           -> 55322152
# Scared To Be Lonely - Brooks Remix       -> 1488210049
# Let It Burn                              -> 59328154
# Pintando El Amor                         -> None
# Living Legend                            -> None
# JOLT                                     -> 43188622
# I Like America & America Likes Me        -> 71563273
# Diamant                                  -> 59940340
# Haute (feat. J Balvin & Chris Brown)     -> 141635337
# Sou + Você                               -> None
# Glad You Came                            -> 68170558
# No Fun                                   -> None
# dashstar* - Yellow Claw Trap Edit        -> 44144848
# Carti                                    -> 10251014
# I Would Like                             -> 292897547
# I Have Nothing - Film Version            -> 657221964
# 2012 (It Ain't The End)                  -> 72927060
# Infinity                                 -> 7046063
# Tell Me                                  -> None
# LoveYou                                  -> None
# ふたりの世界                                   -> None
# Original Sin - Felix Jaehn Remix         -> 93472059
# Womb Heartbeat (No Fade for Looping)     -> None
# Obedient                                 -> 30619444
# This Guy's In Love With You, Pare        -> 54067895
# That's What I Like - Alan Walker Remix   -> 3096540366
# Cry for Me                               -> 106060592
# Chasing Highs - Felix Cartal Remix       -> 171227731
# Ignite - 2016 League Of Legends World Ch -> 78363255
# Stay a While                             -> None
# Suicide Saturday                         -> 65276768
# Adieu                                    -> 62033934
# Golddust - Original Mix                  -> 60860690
# Down (feat. Gucci Mane)                  -> 227654996
# The Way I Are (Dance with Somebody) [fea -> 186458950
# Patience Is A Virtue                     -> None
# Home                                     -> 55530598
# Happiness Does Not Wait                  -> 35496173
# Meri Jaan                                -> 166010891
# Escape                                   -> 162720757
# Find You                                 -> 173983364
# This Is Me (From the Greatest Showman)   -> 95397639
# Heavy Heart                              -> None
# Shooters                                 -> 145854018
# I Love U Bibeh                           -> 30349727
# The Lion and the Lamb                    -> 74995797
# Priceless                                -> 65193423
# Little Red Corvette - 7" Edit - 2019 Rem -> 60236275
# O Mundo É Tão Pequeno - Ao Vivo          -> None
# Cruisin to the Park                      -> 32915203
# All You Need Is Love - Remastered 2015   -> 19925278
# Go Head                                  -> None
# Flowers In The Window                    -> 53324897
# Momma’s House                            -> None
# Songs I Can't Listen To                  -> 48767827
# Lampshades on Fire                       -> 83745856
# Gunz N Butter (feat. Juicy J)            -> 63158001
# Sin (feat. Jaden Smith)                  -> 139758084
# Respect the Game                         -> 67313281
# I'm a Lady - from SMURFS: THE LOST VILLA -> 57414293
# Honest                                   -> 117120404
# Give It Up                               -> 12831442
# Imagine Me & You (feat. FAST BOY)        -> 14515043
# I'll Be There                            -> 6166032
# Chit Chat                                -> None
# Rymden och tillbaks                      -> 9843597
# Vou Fazer Pirraça - Ao Vivo              -> None
# Se Eu Pedir, Cê Volta - Ao Vivo          -> None
# Ruin My Weekend                          -> 19229213
# Mississippi Phone Booth                  -> 17079940
# Redemption (feat. SZA)                   -> 25287487
# --- Saved 100 records to batch_results_streams/results_batch_0279.parquet ---
# I Don't Die                              -> 104396313
# Greetings from Califournia               -> 56402494
# Saint Cecilia                            -> 62959921
# Chills                                   -> 74792958
# Tempo                                    -> 99550857
# Fuck Feelings                            -> 90008409
# Lost                                     -> 49689287
# Say It - Illenium Remix                  -> 165241728
# Afterlife                                -> 73425118
# Stolen Dance                             -> None
# Voldemort                                -> 49350547
# Grytan                                   -> None
# Para Qué Sufrir                          -> None
# Wildfire (feat. Frank Ocean)             -> 131639951
# Mix 'Em With Whiskey                     -> 23232620
# I'm Good (Blue) - Gabry Ponte Remix      -> 2344392240
# Fresh - Single Version                   -> 118796699
# 21                                       -> 82470157
# Kom och rulla i mitt rullande hus        -> 8995255
# We Are                                   -> 66521097
# break da law                             -> 68576222
# Ray Mysterio (feat. Westside Gunn & Conw -> 32310122
# Dreams Come True                         -> None
# Stamp On The Ground                      -> 9143340
# Cuándo empezaré a vivir                  -> None
# If You Know You Know                     -> 86548658
# Joanne                                   -> 93871464
# High (feat. Elton John)                  -> 90729142
# Ven y camina conmigo (feat. Pepe Aguilar -> 54364576
# Supercalifragilisticexpialidocious - Fro -> 120712475
# Mora Saiyyan                             -> None
# Take Control                             -> None
# Kung Fu                                  -> 193350848
# So High                                  -> 49529958
# Aw Shit - Zillakami Solo                 -> 24247933
# Realist In It (feat. Gucci Mane & Offset -> 56426906
# Do Not Disturb (feat. Lil Yachty & Offse -> 98853013
# Midnight                                 -> 98791798
# Car Sick (feat. NAV & Metro Boomin)      -> 72444446
# LIFE                                     -> 54639785
# Day N Night                              -> 9363240
# Goddamn (feat. A Boogie wit da Hoodie)   -> 182022165
# Bigger Than You (feat. Drake & Quavo)    -> 162474394
# SLOWMOTION                               -> 26604248
# Eres Todo Todo - Bolero                  -> 36150062
# 2011                                     -> 37383189
# Beete Lamhein (From "The Train")         -> 203238634
# Peaches (feat. Anne-Marie)               -> 115726570
# Demon Time                               -> 21745896
# Lonely Dance                             -> 33822997
# Tell It To My Heart (feat. Hozier) - KVS -> 260027799
# Why Indiana                              -> 17776133
# Maria Teresa y Danilo                    -> 47187335
# Entre La Espada y La Pared               -> 54346885
# Reverse (feat. G-Eazy)                   -> 140855994
# LA LA                                    -> 63536137
# S1R1                                     -> None
# Memory Bank                              -> 15049338
# Purge                                    -> 29071981
# Window Pain - Outro                      -> 90579364
# Eyes on Fire - Zeds Dead Remix           -> 197843255
# Dil Diyan Gallan - LoFi Mix              -> 416144146
# Yaar Ve (From "Code Name Tiranga")       -> 7399346
# Panic Attack                             -> None
# Act 6                                    -> 13973549
# Headbangeeeeerrrrr!!!!!                  -> 77638885
# Nightmare                                -> 4621706
# Forever In My Mind                       -> None
# Party All The Time                       -> 827463
# The Cut Off (feat. kiLL edward)          -> 92018206
# Boot It Up                               -> 53729045
# Ex-Mørtis                                -> None
# Тримай                                   -> None
# Moth To A Flame (feat. The Weeknd) - Adr -> 19631730
# BEST FRIEND                              -> 47580454
# Slow It Down                             -> 162353516
# The Dreams that Stuff is Made Of         -> 21678349
# Ole Melody                               -> 36519125
# Thanne Thanne                            -> 9333538
# 6's to 9's - Day Wave Remix              -> 118304238
# Abalele                                  -> 39952133
# Madura Veeran                            -> 18132015
# Sahana Saral Thoo                        -> 35572090
# Ayo Technology                           -> 22657043
# Waves (feat. Marissa)                    -> None
# Mission Control                          -> None
# Request Refused                          -> 27328649
# Todos Locos                              -> 49364019
# Oats In The Water                        -> 85440755
# Night Birds                              -> 17794196
# Zoom Zoom                                -> 39325702

# %% [markdown]
# ## 5. Combine Batches & Final Output

# %%
combined_df = pd.DataFrame(new_results)
# Or just load everything from BATCH_DIR if resuming from a broken state
all_files = sorted(BATCH_DIR.glob('results_batch_*.parquet'))
if not combined_df.empty or all_files:
    temp_dfs = [pd.read_parquet(f) for f in all_files]
    final_df = pd.concat(temp_dfs, ignore_index=True)
    
    final_df.to_parquet('spotify_stream_counts.parquet', index=False)
    print(f"Saved {len(final_df)} total stream counts to 'spotify_stream_counts.parquet'")
else:
    print("No data to save.")
# Out:
# Saved 12000 total stream counts to 'spotify_stream_counts.parquet'

# %% [markdown]
# ## 6. Examination of Stream Counts Parquet
# Load the saved parquet file and show the first 10 lines.

# %%
import pandas as pd
df_streams = pd.read_parquet('batch_results_streams/results_batch_0001.parquet')
df_streams.head(10)
# Out:
#                  track_id  stream_count
# 0  0yLdNVWF3Srea0uzk55zFn  2.809638e+09
# 1  4nrPB8O7Y7wsOCJdgXkthe  1.153606e+09
# 2  7oDd86yk8itslrA9HRP2ki  3.189438e+09
# 3  1Qrg8KqiBpW07V7PNxwwwL  2.747259e+09
# 4  5ww2BF9slyYgNOk37BlC4u  2.374237e+09
# 5  4uUG5RXrOk84mYEfFvj3cK  2.343735e+09
# 6  0WtM2NBVQNNJLh6scP13H8  1.839255e+09
# 7  65FftemJ1DbbZ45DUfHJXE  9.196280e+08
# 8  2tTmW7RDtMQtBk7m2rYeSw  2.047428e+09
# 9  78Sw5GDo6AlGwTwanjXbGh  1.753805e+09
