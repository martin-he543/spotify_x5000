# %% [markdown]
# ## Sometimes... You just wanna look at the dataset, but parquets are kinda annoying...

# %%
import polars as pl
import numpy as np

# %%
# 1. Read the file and assign it to a variable (df)
df = pl.read_parquet('spotify_5000.parquet')

# 2. Call head() on the variable
df.head(12)
# Out:
# shape: (12, 39)
# ┌────────────┬────────────┬────────────┬───────────┬───┬─────────┬─────────┬───────────┬───────────┐
# │ track_id   ┆ original_n ┆ original_a ┆ id        ┆ … ┆ valence ┆ tempo   ┆ duration_ ┆ time_sign │
# │ ---        ┆ ame        ┆ rtist      ┆ ---       ┆   ┆ ---     ┆ ---     ┆ ms_right  ┆ ature     │
# │ str        ┆ ---        ┆ ---        ┆ str       ┆   ┆ f64     ┆ f64     ┆ ---       ┆ ---       │
# │            ┆ str        ┆ str        ┆           ┆   ┆         ┆         ┆ i64       ┆ i64       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═════════╪═════════╪═══════════╪═══════════╡
# │ 0yLdNVWF3S ┆ Flowers    ┆ Miley      ┆ 0yLdNVWF3 ┆ … ┆ 0.646   ┆ 117.999 ┆ 200455    ┆ 4         │
# │ rea0uzk55z ┆            ┆ Cyrus      ┆ Srea0uzk5 ┆   ┆         ┆         ┆           ┆           │
# │ Fn         ┆            ┆            ┆ 5zFn      ┆   ┆         ┆         ┆           ┆           │
# ...
